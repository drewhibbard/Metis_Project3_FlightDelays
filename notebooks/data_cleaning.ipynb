# %% [markdown]
# This notebook is purely for data cleaning.  I have placed my raw data into a PostgreSQL database consisting of 5 tables:
#
# 1. Flights - detailed info about each flight in the United States in 2015
# 2. Airports - just a simple table linking the airport code to the full name
# 3. Airlines - just a simple table linking the airline code to the full name
# 4. Aircraft - information about each plane scraped from airfleets.net
# 5. Weather - daily weather summaries from the NOAA
#
# I connect to the database using psycopg2 and then use SQL and pandas to get clean the data and engineer features.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import psycopg2 as pg2 
# %matplotlib inline
sns.set()

password = 'hibbard'
host = 'localhost'
port = 5433

# %%
conn = pg2.connect(database='flights',user='postgres',password=password,host=host,port=port)

# %%
query = '''
SELECT * FROM aircraft LIMIT 10;
'''

pd.read_sql(query,conn)
# Out:
#   tail_num manufacturer model          engine first_flight
# 0   N101DU       Airbus  A220  2 x PW PW1524G   06/10/2018
# 1   N102DU       Airbus  A220  2 x PW PW1524G   07/12/2018
# 2   N103DU       Airbus  A220  2 x PW PW1524G   22/11/2018
# 3   N104DU       Airbus  A220  2 x PW PW1524G   20/12/2018
# 4   N105DU       Airbus  A220  2 x PW PW1524G   03/02/2019
# 5   N106DU       Airbus  A220  2 x PW PW1524G   09/02/2019
# 6   N107DU       Airbus  A220  2 x PW PW1524G   12/02/2019
# 7   N108DQ       Airbus  A220  2 x PW PW1524G   12/04/2019
# 8   N109DU       Airbus  A220  2 x PW PW1524G   23/02/2019
# 9   N110DU       Airbus  A220  2 x PW PW1524G   16/03/2019

# %%
query = '''
SELECT * FROM airlines LIMIT 10;
'''

pd.read_sql(query,conn)
# Out:
#   iata_code                 airline
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways
# 5        OO   Skywest Airlines Inc.
# 6        AS    Alaska Airlines Inc.
# 7        NK        Spirit Air Lines
# 8        WN  Southwest Airlines Co.
# 9        DL    Delta Air Lines Inc.

# %%
query = '''
SELECT * FROM airports;
'''

ports = pd.read_sql(query,conn)

# %%
query = '''
SELECT * FROM flights LIMIT 10;
'''

pd.read_sql(query,conn)
# Out:
#    year  month  day  day_of_week airline  flight_num tail_num orig_airport  \
# 0  2015      1    4            7      US        2075   N713UW          CLT
# 1  2015      1    4            7      US        2086   N712US          CLT
# 2  2015      1    4            7      US         864   N806AW          CLT
# 3  2015      1    4            7      US        2035   N737US          CLT
# 4  2015      1    4            7      AA        2497   N3ABAA          DFW
# 5  2015      1    4            7      AS         473   N794AS          LAX
# 6  2015      1    4            7      B6        1602   N651JB          FLL
# 7  2015      1    4            7      F9        1352   N216FR          IAD
# 8  2015      1    4            7      F9        1102   N912FR          ATL
# 9  2015      1    4            7      NK         709   N502NK          LAX
#
#   dest_airport  sched_depart  ...  arr_time  arr_delay  diverted  cancelled  \
# 0          BNA          2225  ...    2247.0        2.0         0          0
# 1          RIC          2225  ...    2325.0       -2.0         0          0
# 2          ORF          2225  ...    2329.0        1.0         0          0
# 3          JAX          2225  ...    2332.0       -8.0         0          0
# 4          LAX          2225  ...      21.0       31.0         0          0
# 5          SEA          2225  ...     102.0       -4.0         0          0
# 6          JFK          2225  ...     147.0       45.0         0          0
# 7          STL          2225  ...       5.0       20.0         0          0
# 8          CLE          2225  ...      27.0       12.0         0          0
# 9          DTW          2225  ...     709.0       93.0         0          0
#
#    cancel_reason  air_sys_delay  security_delay  airline_delay  \
# 0           None            NaN             NaN            NaN
# 1           None            NaN             NaN            NaN
# 2           None            NaN             NaN            NaN
# 3           None            NaN             NaN            NaN
# 4           None           14.0             0.0           16.0
# 5           None            NaN             NaN            NaN
# 6           None            0.0             0.0            9.0
# 7           None            6.0             0.0           14.0
# 8           None            NaN             NaN            NaN
# 9           None           93.0             0.0            0.0
#
#    late_aircraft_delay  weather_delay
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  1.0            0.0
# 5                  NaN            NaN
# 6                 36.0            0.0
# 7                  0.0            0.0
# 8                  NaN            NaN
# 9                  0.0            0.0
#
# [10 rows x 31 columns]

# %%
query = '''
SELECT * FROM weather;
'''

weather = pd.read_sql(query,conn)

# %%
query = '''
SELECT * FROM aircraft  
INNER JOIN flights 
ON aircraft.tail_num = flights.tail_num
INNER JOIN airlines
ON airlines.iata_code = flights.airline ;
'''

air = pd.read_sql(query,conn)
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3005837 entries, 0 to 3005836
# Data columns (total 38 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   tail_num             object
#  1   manufacturer         object
#  2   model                object
#  3   engine               object
#  4   first_flight         object
#  5   year                 int64
#  6   month                int64
#  7   day                  int64
#  8   day_of_week          int64
#  9   airline              object
#  10  flight_num           int64
#  11  tail_num             object
#  12  orig_airport         object
#  13  dest_airport         object
#  14  sched_depart         int64
#  15  depart_time          float64
#  16  depart_delay         float64
#  17  taxi_out             float64
#  18  wheels_off           float64
#  19  sched_time           float64
#  20  elapsed_time         float64
#  21  air_time             float64
#  22  distance             int64
#  23  wheels_on            float64
#  24  taxi_in              float64
#  25  sched_arr            float64
#  26  arr_time             float64
#  27  arr_delay            float64
#  28  diverted             object
#  29  cancelled            object
#  30  cancel_reason        object
#  31  air_sys_delay        float64
#  32  security_delay       float64
#  33  airline_delay        float64
#  34  late_aircraft_delay  float64
#  35  weather_delay        float64
#  36  iata_code            object
#  37  airline              object
# dtypes: float64(17), int64(7), object(14)
# memory usage: 871.4+ MB

# %%
air.head()
# Out:
#   tail_num manufacturer model                engine first_flight  year  month  \
# 0   N713UW       Airbus  A319  2 x CFMI CFM56-5B6/P   17/06/1999  2015      1
# 1   N712US       Airbus  A319  2 x CFMI CFM56-5B6/P   03/06/1999  2015      1
# 2   N806AW       Airbus  A319      2 x IAE V2524-A5   05/07/1999  2015      1
# 3   N737US       Airbus  A319  2 x CFMI CFM56-5B6/P   20/05/2000  2015      1
# 4   N651JB       Airbus  A320      2 x IAE V2527-A5   07/12/2006  2015      1
#
#    day  day_of_week  airline  ...  diverted cancelled cancel_reason  \
# 0    4            7       US  ...         0         0          None
# 1    4            7       US  ...         0         0          None
# 2    4            7       US  ...         0         0          None
# 3    4            7       US  ...         0         0          None
# 4    4            7       B6  ...         0         0          None
#
#   air_sys_delay  security_delay  airline_delay  late_aircraft_delay  \
# 0           NaN             NaN            NaN                  NaN
# 1           NaN             NaN            NaN                  NaN
# 2           NaN             NaN            NaN                  NaN
# 3           NaN             NaN            NaN                  NaN
# 4           0.0             0.0            9.0                 36.0
#
#    weather_delay  iata_code          airline
# 0            NaN         US  US Airways Inc.
# 1            NaN         US  US Airways Inc.
# 2            NaN         US  US Airways Inc.
# 3            NaN         US  US Airways Inc.
# 4            0.0         B6  JetBlue Airways
#
# [5 rows x 38 columns]

# %%
# raw data provides a year, month and day of flight - convert that to datetime
air['flight_date'] = pd.to_datetime(air[['year','month','day']])

# %%
air['flight_date'] = air.flight_date.dt.date

# %%
weather['date'] = pd.to_datetime(weather['date'])
weather['date'] = weather.date.dt.date

# %% [markdown]
# Merge everything into one dataframe where each row is a unique flight and contains all the necessary information to predict a flight delay.

# %%
df1 = pd.merge(air,weather,left_on=['orig_airport','flight_date'],
              right_on=['airport_code','date'])

# %%
df2 = pd.merge(df1,weather,left_on=['dest_airport','flight_date'],
              right_on=['airport_code','date'])

# %%
df3 = pd.merge(df2,ports,left_on='orig_airport',right_on='iata_code')

# %%
df_raw = pd.merge(df3,ports,left_on='dest_airport',right_on='iata_code')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1580818 entries, 0 to 1580817
# Data columns (total 71 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   tail_num             1580818 non-null  object
#  1   manufacturer         1580818 non-null  object
#  2   model                1580818 non-null  object
#  3   engine               1580818 non-null  object
#  4   first_flight         1580818 non-null  object
#  5   year                 1580818 non-null  int64
#  6   month                1580818 non-null  int64
#  7   day                  1580818 non-null  int64
#  8   day_of_week          1580818 non-null  int64
#  9   airline              1580818 non-null  object
#  10  flight_num           1580818 non-null  int64
#  11  tail_num             1580818 non-null  object
#  12  orig_airport         1580818 non-null  object
#  13  dest_airport         1580818 non-null  object
#  14  sched_depart         1580818 non-null  int64
#  15  depart_time          1568853 non-null  float64
#  16  depart_delay         1568853 non-null  float64
#  17  taxi_out             1568347 non-null  float64
#  18  wheels_off           1568347 non-null  float64
#  19  sched_time           1580815 non-null  float64
#  20  elapsed_time         1564329 non-null  float64
#  21  air_time             1564329 non-null  float64
#  22  distance             1580818 non-null  int64
#  23  wheels_on            1567627 non-null  float64
#  24  taxi_in              1567627 non-null  float64
#  25  sched_arr            1580818 non-null  float64
#  26  arr_time             1567627 non-null  float64
#  27  arr_delay            1564329 non-null  float64
#  28  diverted             1580818 non-null  object
#  29  cancelled            1580818 non-null  object
#  30  cancel_reason        12564 non-null    object
#  31  air_sys_delay        305827 non-null   float64
#  32  security_delay       305827 non-null   float64
#  33  airline_delay        305827 non-null   float64
#  34  late_aircraft_delay  305827 non-null   float64
#  35  weather_delay        305827 non-null   float64
#  36  iata_code_x          1580818 non-null  object
#  37  airline              1580818 non-null  object
#  38  flight_date          1580818 non-null  object
#  39  station_x            1580818 non-null  object
#  40  name_x               1580818 non-null  object
#  41  date_x               1580818 non-null  object
#  42  avg_wind_x           1580818 non-null  float64
#  43  precip_x             1580818 non-null  float64
#  44  snow_x               1580818 non-null  float64
#  45  max_temp_x           1580818 non-null  float64
#  46  min_temp_x           1580818 non-null  float64
#  47  airport_code_x       1580818 non-null  object
#  48  station_y            1580818 non-null  object
#  49  name_y               1580818 non-null  object
#  50  date_y               1580818 non-null  object
#  51  avg_wind_y           1580818 non-null  float64
#  52  precip_y             1580818 non-null  float64
#  53  snow_y               1580818 non-null  float64
#  54  max_temp_y           1580818 non-null  float64
#  55  min_temp_y           1580818 non-null  float64
#  56  airport_code_y       1580818 non-null  object
#  57  iata_code_y          1580818 non-null  object
#  58  airport_x            1580818 non-null  object
#  59  city_x               1580818 non-null  object
#  60  state_x              1580818 non-null  object
#  61  country_x            1580818 non-null  object
#  62  lat_x                1580818 non-null  float64
#  63  long_x               1580818 non-null  float64
#  64  iata_code            1580818 non-null  object
#  65  airport_y            1580818 non-null  object
#  66  city_y               1580818 non-null  object
#  67  state_y              1580818 non-null  object
#  68  country_y            1580818 non-null  object
#  69  lat_y                1580818 non-null  float64
#  70  long_y               1580818 non-null  float64
# dtypes: float64(31), int64(7), object(33)
# memory usage: 868.4+ MB

# %%
df_raw.columns
# Out:
# Index(['tail_num', 'manufacturer', 'model', 'engine', 'first_flight', 'year',
#        'month', 'day', 'day_of_week', 'airline', 'flight_num', 'tail_num',
#        'orig_airport', 'dest_airport', 'sched_depart', 'depart_time',
#        'depart_delay', 'taxi_out', 'wheels_off', 'sched_time', 'elapsed_time',
#        'air_time', 'distance', 'wheels_on', 'taxi_in', 'sched_arr', 'arr_time',
#        'arr_delay', 'diverted', 'cancelled', 'cancel_reason', 'air_sys_delay',
#        'security_delay', 'airline_delay', 'late_aircraft_delay',
#        'weather_delay', 'iata_code_x', 'airline', 'flight_date', 'station_x',
#        'name_x', 'date_x', 'avg_wind_x', 'precip_x', 'snow_x', 'max_temp_x',
#        'min_temp_x', 'airport_code_x', 'station_y', 'name_y', 'date_y',
#        'avg_wind_y', 'precip_y', 'snow_y', 'max_temp_y', 'min_temp_y',
#        'airport_code_y', 'iata_code_y', 'airport_x', 'city_x', 'state_x',
#        'country_x', 'lat_x', 'long_x', 'iata_code', 'airport_y', 'city_y',
#        'state_y', 'country_y', 'lat_y', 'long_y'],
#       dtype='object')

# %%
# rename some of the columns so I know which ones are duplicates and can be dropped

df_raw.columns = ['tail_num', 'manufacturer', 'model', 'engine', 'first_flight', 'year',
       'month', 'day', 'day_of_week', 'airline_drop', 'flight_num', 'tail_num_drop',
       'orig_airport', 'dest_airport', 'sched_depart', 'depart_time',
       'depart_delay', 'taxi_out', 'wheels_off', 'sched_time', 'elapsed_time',
       'air_time', 'distance', 'wheels_on', 'taxi_in', 'sched_arr', 'arr_time',
       'arr_delay', 'diverted', 'cancelled', 'cancel_reason', 'air_sys_delay',
       'security_delay', 'airline_delay', 'late_aircraft_delay',
       'weather_delay', 'iata_code_x', 'airline', 'flight_date', 'station_orig',
       'name_orig', 'date_x', 'avg_wind_orig', 'precip_orig', 'snow_orig', 'max_temp_orig',
       'min_temp_orig', 'airport_code_x', 'station_dest', 'name_dest', 'date_y',
       'avg_wind_dest', 'precip_dest', 'snow_dest', 'max_temp_dest', 'min_temp_dest',
       'airport_code_dest', 'iata_code_orig', 'airport_name_orig', 'city_orig', 'state_orig',
       'country_orig', 'lat_orig', 'long_orig', 'iata_code_dest', 'airport_dest', 'city_dest',
       'state_dest', 'country_dest', 'lat_dest', 'long_dest']

# %%
pd.options.display.max_columns = None

# %%
df_raw.drop(['tail_num_drop','airline_drop','date_x','date_y'],axis=1,inplace=True)

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model               engine first_flight  year  month  \
# 0   N502NK       Airbus  A319     2 x IAE V2524-A5   11/03/2005  2015      1
# 1   N372DA       Boeing   737  2 x CFMI CFM56-7B26   23/09/1998  2015      1
# 2   N550NW       Boeing   757        2 x PW PW2037   02/06/2001  2015      1
# 3   N693DL       Boeing   757        2 x PW PW2037   27/09/1998  2015      1
# 4   N6706Q       Boeing   757        2 x PW PW2037   21/03/2000  2015      1
#
#    day  day_of_week  flight_num orig_airport dest_airport  sched_depart  \
# 0    4            7         709          LAX          DTW          2225
# 1    4            7        1806          LAX          DTW           928
# 2    4            7        1706          LAX          DTW          1135
# 3    4            7         870          LAX          DTW          1330
# 4    5            1        1876          LAX          DTW          1330
#
#    depart_time  depart_delay  taxi_out  wheels_off  sched_time  elapsed_time  \
# 0       2338.0          73.0      11.0      2349.0       251.0         271.0
# 1        944.0          16.0      15.0       959.0       267.0         262.0
# 2       1159.0          24.0      21.0      1220.0       269.0         268.0
# 3       1330.0           0.0      21.0      1351.0       261.0         262.0
# 4       1328.0          -2.0      17.0      1345.0       267.0         268.0
#
#    air_time  distance  wheels_on  taxi_in  sched_arr  arr_time  arr_delay  \
# 0     247.0      1979      656.0     13.0      536.0     709.0       93.0
# 1     238.0      1979     1657.0      9.0     1655.0    1706.0       11.0
# 2     239.0      1979     1919.0      8.0     1904.0    1927.0       23.0
# 3     232.0      1979     2043.0      9.0     2051.0    2052.0        1.0
# 4     237.0      1979     2042.0     14.0     2057.0    2056.0       -1.0
#
#   diverted cancelled cancel_reason  air_sys_delay  security_delay  \
# 0        0         0          None           93.0             0.0
# 1        0         0          None            NaN             NaN
# 2        0         0          None            0.0             0.0
# 3        0         0          None            NaN             NaN
# 4        0         0          None            NaN             NaN
#
#    airline_delay  late_aircraft_delay  weather_delay iata_code_x  \
# 0            0.0                  0.0            0.0          NK
# 1            NaN                  NaN            NaN          DL
# 2           19.0                  4.0            0.0          DL
# 3            NaN                  NaN            NaN          DL
# 4            NaN                  NaN            NaN          DL
#
#                 airline flight_date station_orig  \
# 0      Spirit Air Lines  2015-01-04  USW00023174
# 1  Delta Air Lines Inc.  2015-01-04  USW00023174
# 2  Delta Air Lines Inc.  2015-01-04  USW00023174
# 3  Delta Air Lines Inc.  2015-01-04  USW00023174
# 4  Delta Air Lines Inc.  2015-01-05  USW00023174
#
#                                   name_orig  avg_wind_orig  precip_orig  \
# 0  LOS ANGELES INTERNATIONAL AIRPORT, CA US           4.70          0.0
# 1  LOS ANGELES INTERNATIONAL AIRPORT, CA US           4.70          0.0
# 2  LOS ANGELES INTERNATIONAL AIRPORT, CA US           4.70          0.0
# 3  LOS ANGELES INTERNATIONAL AIRPORT, CA US           4.70          0.0
# 4  LOS ANGELES INTERNATIONAL AIRPORT, CA US           5.59          0.0
#
#    snow_orig  max_temp_orig  min_temp_orig airport_code_x station_dest  \
# 0        0.0           61.0           42.0            LAX  USW00094847
# 1        0.0           61.0           42.0            LAX  USW00094847
# 2        0.0           61.0           42.0            LAX  USW00094847
# 3        0.0           61.0           42.0            LAX  USW00094847
# 4        0.0           79.0           50.0            LAX  USW00094847
#
#                       name_dest  avg_wind_dest  precip_dest  snow_dest  \
# 0  DETROIT METRO AIRPORT, MI US          11.86         0.12        0.8
# 1  DETROIT METRO AIRPORT, MI US          11.86         0.12        0.8
# 2  DETROIT METRO AIRPORT, MI US          11.86         0.12        0.8
# 3  DETROIT METRO AIRPORT, MI US          11.86         0.12        0.8
# 4  DETROIT METRO AIRPORT, MI US          13.65         0.00        0.2
#
#    max_temp_dest  min_temp_dest airport_code_dest iata_code_orig  \
# 0           36.0           19.0               DTW            LAX
# 1           36.0           19.0               DTW            LAX
# 2           36.0           19.0               DTW            LAX
# 3           36.0           19.0               DTW            LAX
# 4           19.0            8.0               DTW            LAX
#
#                    airport_name_orig    city_orig state_orig country_orig  \
# 0  Los Angeles International Airport  Los Angeles         CA          USA
# 1  Los Angeles International Airport  Los Angeles         CA          USA
# 2  Los Angeles International Airport  Los Angeles         CA          USA
# 3  Los Angeles International Airport  Los Angeles         CA          USA
# 4  Los Angeles International Airport  Los Angeles         CA          USA
#
#    lat_orig  long_orig iata_code_dest                  airport_dest city_dest  \
# 0  33.94254 -118.40807            DTW  Detroit Metropolitan Airport   Detroit
# 1  33.94254 -118.40807            DTW  Detroit Metropolitan Airport   Detroit
# 2  33.94254 -118.40807            DTW  Detroit Metropolitan Airport   Detroit
# 3  33.94254 -118.40807            DTW  Detroit Metropolitan Airport   Detroit
# 4  33.94254 -118.40807            DTW  Detroit Metropolitan Airport   Detroit
#
#   state_dest country_dest  lat_dest  long_dest
# 0         MI          USA  42.21206  -83.34884
# 1         MI          USA  42.21206  -83.34884
# 2         MI          USA  42.21206  -83.34884
# 3         MI          USA  42.21206  -83.34884
# 4         MI          USA  42.21206  -83.34884

# %%
df_raw.drop(['airport_code_x','airport_code_dest','iata_code_orig','iata_code_dest',
            'station_orig','station_dest','name_orig','name_dest'],axis=1,inplace=True)

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model               engine first_flight  year  month  \
# 0   N502NK       Airbus  A319     2 x IAE V2524-A5   11/03/2005  2015      1
# 1   N372DA       Boeing   737  2 x CFMI CFM56-7B26   23/09/1998  2015      1
# 2   N550NW       Boeing   757        2 x PW PW2037   02/06/2001  2015      1
# 3   N693DL       Boeing   757        2 x PW PW2037   27/09/1998  2015      1
# 4   N6706Q       Boeing   757        2 x PW PW2037   21/03/2000  2015      1
#
#    day  day_of_week  flight_num orig_airport dest_airport  sched_depart  \
# 0    4            7         709          LAX          DTW          2225
# 1    4            7        1806          LAX          DTW           928
# 2    4            7        1706          LAX          DTW          1135
# 3    4            7         870          LAX          DTW          1330
# 4    5            1        1876          LAX          DTW          1330
#
#    depart_time  depart_delay  taxi_out  wheels_off  sched_time  elapsed_time  \
# 0       2338.0          73.0      11.0      2349.0       251.0         271.0
# 1        944.0          16.0      15.0       959.0       267.0         262.0
# 2       1159.0          24.0      21.0      1220.0       269.0         268.0
# 3       1330.0           0.0      21.0      1351.0       261.0         262.0
# 4       1328.0          -2.0      17.0      1345.0       267.0         268.0
#
#    air_time  distance  wheels_on  taxi_in  sched_arr  arr_time  arr_delay  \
# 0     247.0      1979      656.0     13.0      536.0     709.0       93.0
# 1     238.0      1979     1657.0      9.0     1655.0    1706.0       11.0
# 2     239.0      1979     1919.0      8.0     1904.0    1927.0       23.0
# 3     232.0      1979     2043.0      9.0     2051.0    2052.0        1.0
# 4     237.0      1979     2042.0     14.0     2057.0    2056.0       -1.0
#
#   diverted cancelled cancel_reason  air_sys_delay  security_delay  \
# 0        0         0          None           93.0             0.0
# 1        0         0          None            NaN             NaN
# 2        0         0          None            0.0             0.0
# 3        0         0          None            NaN             NaN
# 4        0         0          None            NaN             NaN
#
#    airline_delay  late_aircraft_delay  weather_delay iata_code_x  \
# 0            0.0                  0.0            0.0          NK
# 1            NaN                  NaN            NaN          DL
# 2           19.0                  4.0            0.0          DL
# 3            NaN                  NaN            NaN          DL
# 4            NaN                  NaN            NaN          DL
#
#                 airline flight_date  avg_wind_orig  precip_orig  snow_orig  \
# 0      Spirit Air Lines  2015-01-04           4.70          0.0        0.0
# 1  Delta Air Lines Inc.  2015-01-04           4.70          0.0        0.0
# 2  Delta Air Lines Inc.  2015-01-04           4.70          0.0        0.0
# 3  Delta Air Lines Inc.  2015-01-04           4.70          0.0        0.0
# 4  Delta Air Lines Inc.  2015-01-05           5.59          0.0        0.0
#
#    max_temp_orig  min_temp_orig  avg_wind_dest  precip_dest  snow_dest  \
# 0           61.0           42.0          11.86         0.12        0.8
# 1           61.0           42.0          11.86         0.12        0.8
# 2           61.0           42.0          11.86         0.12        0.8
# 3           61.0           42.0          11.86         0.12        0.8
# 4           79.0           50.0          13.65         0.00        0.2
#
#    max_temp_dest  min_temp_dest                  airport_name_orig  \
# 0           36.0           19.0  Los Angeles International Airport
# 1           36.0           19.0  Los Angeles International Airport
# 2           36.0           19.0  Los Angeles International Airport
# 3           36.0           19.0  Los Angeles International Airport
# 4           19.0            8.0  Los Angeles International Airport
#
#      city_orig state_orig country_orig  lat_orig  long_orig  \
# 0  Los Angeles         CA          USA  33.94254 -118.40807
# 1  Los Angeles         CA          USA  33.94254 -118.40807
# 2  Los Angeles         CA          USA  33.94254 -118.40807
# 3  Los Angeles         CA          USA  33.94254 -118.40807
# 4  Los Angeles         CA          USA  33.94254 -118.40807
#
#                    airport_dest city_dest state_dest country_dest  lat_dest  \
# 0  Detroit Metropolitan Airport   Detroit         MI          USA  42.21206
# 1  Detroit Metropolitan Airport   Detroit         MI          USA  42.21206
# 2  Detroit Metropolitan Airport   Detroit         MI          USA  42.21206
# 3  Detroit Metropolitan Airport   Detroit         MI          USA  42.21206
# 4  Detroit Metropolitan Airport   Detroit         MI          USA  42.21206
#
#    long_dest
# 0  -83.34884
# 1  -83.34884
# 2  -83.34884
# 3  -83.34884
# 4  -83.34884

# %%
df_raw.drop('year',axis=1,inplace=True)

# %%
df_raw.columns = ['tail_num', 'manufacturer', 'model', 'engine', 'first_flight', 'month',
       'day', 'day_of_week', 'flight_num', 'orig_airport', 'dest_airport',
       'sched_depart', 'depart_time', 'depart_delay', 'taxi_out', 'wheels_off',
       'sched_time', 'elapsed_time', 'air_time', 'distance', 'wheels_on',
       'taxi_in', 'sched_arr', 'arr_time', 'arr_delay', 'diverted',
       'cancelled', 'cancel_reason', 'air_sys_delay', 'security_delay',
       'airline_delay', 'late_aircraft_delay', 'weather_delay', 'airline_code',
       'airline_name', 'flight_date', 'avg_wind_orig', 'precip_orig', 'snow_orig',
       'max_temp_orig', 'min_temp_orig', 'avg_wind_dest', 'precip_dest',
       'snow_dest', 'max_temp_dest', 'min_temp_dest', 'airport_name_orig',
       'city_orig', 'state_orig', 'country_orig', 'lat_orig', 'long_orig',
       'airport_dest', 'city_dest', 'state_dest', 'country_dest', 'lat_dest',
       'long_dest']

# %% [markdown]
# Engine information is a string which typically indicates the number of engines and model in an odd format.  I will extract just the manufacturer abbreviation, keep that as a column, and add in a translation to the full name as well.

# %%
df_raw[['num','engine_a']] = df_raw.engine.str.split(' x ',expand=True)

# %%
df_raw.drop(['engine','num'],axis=1,inplace=True)

# %%
df_raw[['engine_manufacturer','a','b']] = df_raw.engine_a.str.split(' ',expand=True)

# %%
df_raw.drop(['a','b'],axis=1,inplace=True)

# %%
df_raw.engine_manufacturer.unique()
# Out:
# array(['IAE', 'CFMI', 'PW', 'GE', '', 'RR', 'BMW', 'Genx-1b74/75/P1',
#        'GEnx-1B'], dtype=object)

# %%
df_raw.engine_manufacturer.replace('Genx-1b74/75/P1','GE',inplace=True)
df_raw.engine_manufacturer.replace('GEnx-1B','GE',inplace=True)

# %%
df_raw.engine_manufacturer.unique()
# Out:
# array(['IAE', 'CFMI', 'PW', 'GE', '', 'RR', 'BMW'], dtype=object)

# %%
df_raw.engine_manufacturer.value_counts()
# Out:
# CFMI    1033516
# IAE      293573
# PW       118932
# BMW       81778
# RR        29193
# GE        16655
#            7171
# Name: engine_manufacturer, dtype: int64

# %%
df_raw = df_raw[df_raw.engine_manufacturer!='']

# %%
df_raw.drop('engine_a',axis=1,inplace=True)

# %% [markdown]
# The raw data from airfleets.net provided the date of each aircraft's first flight, which I translate into an age of the aircraft in years.

# %%
# last 4 digits of the string date is the year
df_raw['year_plane_made'] = df_raw.first_flight.str[-4:]

# %%
df_raw.year_plane_made.value_counts()
# Out:
# 2001    141016
# 2000    135319
# 1999    101414
# 2006     96016
# 1998     87627
# 2004     75235
# 2002     75220
# 2007     73130
# 2005     69367
# 2008     66516
# nown     66495
# 2012     58561
# 2003     54918
# 2014     48658
# 2011     41703
# 2009     38873
# 2013     35688
# 1997     30500
# 1991     29829
# 1992     29669
# 2010     28404
# 1993     28238
# 1994     28021
# 1995     24939
# 1996     24099
# 2015     23131
# 1990     15200
# 1988     14374
# 1987      9957
# 1986      7826
# 1985      7782
# 1989      3169
# 1984      2753
# Name: year_plane_made, dtype: int64

# %%
df_raw = df_raw[df_raw.year_plane_made!='nown']

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model first_flight  month  day  day_of_week  \
# 0   N502NK       Airbus  A319   11/03/2005      1    4            7
# 1   N372DA       Boeing   737   23/09/1998      1    4            7
# 2   N550NW       Boeing   757   02/06/2001      1    4            7
# 3   N693DL       Boeing   757   27/09/1998      1    4            7
# 4   N6706Q       Boeing   757   21/03/2000      1    5            1
#
#    flight_num orig_airport dest_airport  sched_depart  depart_time  \
# 0         709          LAX          DTW          2225       2338.0
# 1        1806          LAX          DTW           928        944.0
# 2        1706          LAX          DTW          1135       1159.0
# 3         870          LAX          DTW          1330       1330.0
# 4        1876          LAX          DTW          1330       1328.0
#
#    depart_delay  taxi_out  wheels_off  sched_time  elapsed_time  air_time  \
# 0          73.0      11.0      2349.0       251.0         271.0     247.0
# 1          16.0      15.0       959.0       267.0         262.0     238.0
# 2          24.0      21.0      1220.0       269.0         268.0     239.0
# 3           0.0      21.0      1351.0       261.0         262.0     232.0
# 4          -2.0      17.0      1345.0       267.0         268.0     237.0
#
#    distance  wheels_on  taxi_in  sched_arr  arr_time  arr_delay diverted  \
# 0      1979      656.0     13.0      536.0     709.0       93.0        0
# 1      1979     1657.0      9.0     1655.0    1706.0       11.0        0
# 2      1979     1919.0      8.0     1904.0    1927.0       23.0        0
# 3      1979     2043.0      9.0     2051.0    2052.0        1.0        0
# 4      1979     2042.0     14.0     2057.0    2056.0       -1.0        0
#
#   cancelled cancel_reason  air_sys_delay  security_delay  airline_delay  \
# 0         0          None           93.0             0.0            0.0
# 1         0          None            NaN             NaN            NaN
# 2         0          None            0.0             0.0           19.0
# 3         0          None            NaN             NaN            NaN
# 4         0          None            NaN             NaN            NaN
#
#    late_aircraft_delay  weather_delay airline_code          airline_name  \
# 0                  0.0            0.0           NK      Spirit Air Lines
# 1                  NaN            NaN           DL  Delta Air Lines Inc.
# 2                  4.0            0.0           DL  Delta Air Lines Inc.
# 3                  NaN            NaN           DL  Delta Air Lines Inc.
# 4                  NaN            NaN           DL  Delta Air Lines Inc.
#
#   flight_date  avg_wind_orig  precip_orig  snow_orig  max_temp_orig  \
# 0  2015-01-04           4.70          0.0        0.0           61.0
# 1  2015-01-04           4.70          0.0        0.0           61.0
# 2  2015-01-04           4.70          0.0        0.0           61.0
# 3  2015-01-04           4.70          0.0        0.0           61.0
# 4  2015-01-05           5.59          0.0        0.0           79.0
#
#    min_temp_orig  avg_wind_dest  precip_dest  snow_dest  max_temp_dest  \
# 0           42.0          11.86         0.12        0.8           36.0
# 1           42.0          11.86         0.12        0.8           36.0
# 2           42.0          11.86         0.12        0.8           36.0
# 3           42.0          11.86         0.12        0.8           36.0
# 4           50.0          13.65         0.00        0.2           19.0
#
#    min_temp_dest                  airport_name_orig    city_orig state_orig  \
# 0           19.0  Los Angeles International Airport  Los Angeles         CA
# 1           19.0  Los Angeles International Airport  Los Angeles         CA
# 2           19.0  Los Angeles International Airport  Los Angeles         CA
# 3           19.0  Los Angeles International Airport  Los Angeles         CA
# 4            8.0  Los Angeles International Airport  Los Angeles         CA
#
#   country_orig  lat_orig  long_orig                  airport_dest city_dest  \
# 0          USA  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit
# 1          USA  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit
# 2          USA  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit
# 3          USA  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit
# 4          USA  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit
#
#   state_dest country_dest  lat_dest  long_dest engine_manufacturer  \
# 0         MI          USA  42.21206  -83.34884                 IAE
# 1         MI          USA  42.21206  -83.34884                CFMI
# 2         MI          USA  42.21206  -83.34884                  PW
# 3         MI          USA  42.21206  -83.34884                  PW
# 4         MI          USA  42.21206  -83.34884                  PW
#
#   year_plane_made
# 0            2005
# 1            1998
# 2            2001
# 3            1998
# 4            2000

# %%
df_raw['sched_depart'] = df_raw.sched_depart.astype(str).str.zfill(4)

# %%
df_raw['hour'] = df_raw.sched_depart.str[:2]

# %%
df_raw.hour.unique()
# Out:
# array(['22', '09', '11', '13', '07', '23', '00', '21', '06', '14', '16',
#        '15', '10', '08', '05', '12', '17', '19', '18', '20', '01', '02'],
#       dtype=object)

# %%
df_raw.drop('sched_depart',axis=1,inplace=True)

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model first_flight  month  day  day_of_week  \
# 0   N502NK       Airbus  A319   11/03/2005      1    4            7
# 1   N372DA       Boeing   737   23/09/1998      1    4            7
# 2   N550NW       Boeing   757   02/06/2001      1    4            7
# 3   N693DL       Boeing   757   27/09/1998      1    4            7
# 4   N6706Q       Boeing   757   21/03/2000      1    5            1
#
#    flight_num orig_airport dest_airport  depart_time  depart_delay  taxi_out  \
# 0         709          LAX          DTW       2338.0          73.0      11.0
# 1        1806          LAX          DTW        944.0          16.0      15.0
# 2        1706          LAX          DTW       1159.0          24.0      21.0
# 3         870          LAX          DTW       1330.0           0.0      21.0
# 4        1876          LAX          DTW       1328.0          -2.0      17.0
#
#    wheels_off  sched_time  elapsed_time  air_time  distance  wheels_on  \
# 0      2349.0       251.0         271.0     247.0      1979      656.0
# 1       959.0       267.0         262.0     238.0      1979     1657.0
# 2      1220.0       269.0         268.0     239.0      1979     1919.0
# 3      1351.0       261.0         262.0     232.0      1979     2043.0
# 4      1345.0       267.0         268.0     237.0      1979     2042.0
#
#    taxi_in  sched_arr  arr_time  arr_delay diverted cancelled cancel_reason  \
# 0     13.0      536.0     709.0       93.0        0         0          None
# 1      9.0     1655.0    1706.0       11.0        0         0          None
# 2      8.0     1904.0    1927.0       23.0        0         0          None
# 3      9.0     2051.0    2052.0        1.0        0         0          None
# 4     14.0     2057.0    2056.0       -1.0        0         0          None
#
#    air_sys_delay  security_delay  airline_delay  late_aircraft_delay  \
# 0           93.0             0.0            0.0                  0.0
# 1            NaN             NaN            NaN                  NaN
# 2            0.0             0.0           19.0                  4.0
# 3            NaN             NaN            NaN                  NaN
# 4            NaN             NaN            NaN                  NaN
#
#    weather_delay airline_code          airline_name flight_date  \
# 0            0.0           NK      Spirit Air Lines  2015-01-04
# 1            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 2            0.0           DL  Delta Air Lines Inc.  2015-01-04
# 3            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 4            NaN           DL  Delta Air Lines Inc.  2015-01-05
#
#    avg_wind_orig  precip_orig  snow_orig  max_temp_orig  min_temp_orig  \
# 0           4.70          0.0        0.0           61.0           42.0
# 1           4.70          0.0        0.0           61.0           42.0
# 2           4.70          0.0        0.0           61.0           42.0
# 3           4.70          0.0        0.0           61.0           42.0
# 4           5.59          0.0        0.0           79.0           50.0
#
#    avg_wind_dest  precip_dest  snow_dest  max_temp_dest  min_temp_dest  \
# 0          11.86         0.12        0.8           36.0           19.0
# 1          11.86         0.12        0.8           36.0           19.0
# 2          11.86         0.12        0.8           36.0           19.0
# 3          11.86         0.12        0.8           36.0           19.0
# 4          13.65         0.00        0.2           19.0            8.0
#
#                    airport_name_orig    city_orig state_orig country_orig  \
# 0  Los Angeles International Airport  Los Angeles         CA          USA
# 1  Los Angeles International Airport  Los Angeles         CA          USA
# 2  Los Angeles International Airport  Los Angeles         CA          USA
# 3  Los Angeles International Airport  Los Angeles         CA          USA
# 4  Los Angeles International Airport  Los Angeles         CA          USA
#
#    lat_orig  long_orig                  airport_dest city_dest state_dest  \
# 0  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 1  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 2  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 3  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 4  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
#
#   country_dest  lat_dest  long_dest engine_manufacturer year_plane_made hour
# 0          USA  42.21206  -83.34884                 IAE            2005   22
# 1          USA  42.21206  -83.34884                CFMI            1998   09
# 2          USA  42.21206  -83.34884                  PW            2001   11
# 3          USA  42.21206  -83.34884                  PW            1998   13
# 4          USA  42.21206  -83.34884                  PW            2000   13

# %%
# data source provided numerous delay reasons, I want the aggregate total delay

df_raw['total_delay'] = df_raw.air_sys_delay + df_raw.security_delay + df_raw.airline_delay + df_raw.late_aircraft_delay + df_raw.weather_delay

# %%
# turn the continuous variable 'total delay' into a binary delayed/not delayed

df_raw['delayed'] = df_raw.total_delay>0

# %%
df_raw.delayed.value_counts()
# Out:
# False    1212612
# True      294540
# Name: delayed, dtype: int64

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model first_flight  month  day  day_of_week  \
# 0   N502NK       Airbus  A319   11/03/2005      1    4            7
# 1   N372DA       Boeing   737   23/09/1998      1    4            7
# 2   N550NW       Boeing   757   02/06/2001      1    4            7
# 3   N693DL       Boeing   757   27/09/1998      1    4            7
# 4   N6706Q       Boeing   757   21/03/2000      1    5            1
#
#    flight_num orig_airport dest_airport  depart_time  depart_delay  taxi_out  \
# 0         709          LAX          DTW       2338.0          73.0      11.0
# 1        1806          LAX          DTW        944.0          16.0      15.0
# 2        1706          LAX          DTW       1159.0          24.0      21.0
# 3         870          LAX          DTW       1330.0           0.0      21.0
# 4        1876          LAX          DTW       1328.0          -2.0      17.0
#
#    wheels_off  sched_time  elapsed_time  air_time  distance  wheels_on  \
# 0      2349.0       251.0         271.0     247.0      1979      656.0
# 1       959.0       267.0         262.0     238.0      1979     1657.0
# 2      1220.0       269.0         268.0     239.0      1979     1919.0
# 3      1351.0       261.0         262.0     232.0      1979     2043.0
# 4      1345.0       267.0         268.0     237.0      1979     2042.0
#
#    taxi_in  sched_arr  arr_time  arr_delay diverted cancelled cancel_reason  \
# 0     13.0      536.0     709.0       93.0        0         0          None
# 1      9.0     1655.0    1706.0       11.0        0         0          None
# 2      8.0     1904.0    1927.0       23.0        0         0          None
# 3      9.0     2051.0    2052.0        1.0        0         0          None
# 4     14.0     2057.0    2056.0       -1.0        0         0          None
#
#    air_sys_delay  security_delay  airline_delay  late_aircraft_delay  \
# 0           93.0             0.0            0.0                  0.0
# 1            NaN             NaN            NaN                  NaN
# 2            0.0             0.0           19.0                  4.0
# 3            NaN             NaN            NaN                  NaN
# 4            NaN             NaN            NaN                  NaN
#
#    weather_delay airline_code          airline_name flight_date  \
# 0            0.0           NK      Spirit Air Lines  2015-01-04
# 1            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 2            0.0           DL  Delta Air Lines Inc.  2015-01-04
# 3            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 4            NaN           DL  Delta Air Lines Inc.  2015-01-05
#
#    avg_wind_orig  precip_orig  snow_orig  max_temp_orig  min_temp_orig  \
# 0           4.70          0.0        0.0           61.0           42.0
# 1           4.70          0.0        0.0           61.0           42.0
# 2           4.70          0.0        0.0           61.0           42.0
# 3           4.70          0.0        0.0           61.0           42.0
# 4           5.59          0.0        0.0           79.0           50.0
#
#    avg_wind_dest  precip_dest  snow_dest  max_temp_dest  min_temp_dest  \
# 0          11.86         0.12        0.8           36.0           19.0
# 1          11.86         0.12        0.8           36.0           19.0
# 2          11.86         0.12        0.8           36.0           19.0
# 3          11.86         0.12        0.8           36.0           19.0
# 4          13.65         0.00        0.2           19.0            8.0
#
#                    airport_name_orig    city_orig state_orig country_orig  \
# 0  Los Angeles International Airport  Los Angeles         CA          USA
# 1  Los Angeles International Airport  Los Angeles         CA          USA
# 2  Los Angeles International Airport  Los Angeles         CA          USA
# 3  Los Angeles International Airport  Los Angeles         CA          USA
# 4  Los Angeles International Airport  Los Angeles         CA          USA
#
#    lat_orig  long_orig                  airport_dest city_dest state_dest  \
# 0  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 1  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 2  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 3  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 4  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
#
#   country_dest  lat_dest  long_dest engine_manufacturer year_plane_made hour  \
# 0          USA  42.21206  -83.34884                 IAE            2005   22
# 1          USA  42.21206  -83.34884                CFMI            1998   09
# 2          USA  42.21206  -83.34884                  PW            2001   11
# 3          USA  42.21206  -83.34884                  PW            1998   13
# 4          USA  42.21206  -83.34884                  PW            2000   13
#
#    total_delay  delayed
# 0         93.0     True
# 1          NaN    False
# 2         23.0     True
# 3          NaN    False
# 4          NaN    False

# %%
df_raw['aircraft_age'] = 2015 - df_raw.year_plane_made.astype(int)

# %%
df_raw.drop(['year_plane_made','first_flight'],axis=1,inplace=True)

# %%
df_raw.aircraft_age.value_counts()
# Out:
# 14    141016
# 15    135319
# 16    101414
# 9      96016
# 17     87627
# 11     75235
# 13     75220
# 8      73130
# 10     69367
# 7      66516
# 3      58561
# 12     54918
# 1      48658
# 4      41703
# 6      38873
# 2      35688
# 18     30500
# 24     29829
# 23     29669
# 5      28404
# 22     28238
# 21     28021
# 20     24939
# 19     24099
# 0      23131
# 25     15200
# 27     14374
# 28      9957
# 29      7826
# 30      7782
# 26      3169
# 31      2753
# Name: aircraft_age, dtype: int64

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model  month  day  day_of_week  flight_num  \
# 0   N502NK       Airbus  A319      1    4            7         709
# 1   N372DA       Boeing   737      1    4            7        1806
# 2   N550NW       Boeing   757      1    4            7        1706
# 3   N693DL       Boeing   757      1    4            7         870
# 4   N6706Q       Boeing   757      1    5            1        1876
#
#   orig_airport dest_airport  depart_time  depart_delay  taxi_out  wheels_off  \
# 0          LAX          DTW       2338.0          73.0      11.0      2349.0
# 1          LAX          DTW        944.0          16.0      15.0       959.0
# 2          LAX          DTW       1159.0          24.0      21.0      1220.0
# 3          LAX          DTW       1330.0           0.0      21.0      1351.0
# 4          LAX          DTW       1328.0          -2.0      17.0      1345.0
#
#    sched_time  elapsed_time  air_time  distance  wheels_on  taxi_in  \
# 0       251.0         271.0     247.0      1979      656.0     13.0
# 1       267.0         262.0     238.0      1979     1657.0      9.0
# 2       269.0         268.0     239.0      1979     1919.0      8.0
# 3       261.0         262.0     232.0      1979     2043.0      9.0
# 4       267.0         268.0     237.0      1979     2042.0     14.0
#
#    sched_arr  arr_time  arr_delay diverted cancelled cancel_reason  \
# 0      536.0     709.0       93.0        0         0          None
# 1     1655.0    1706.0       11.0        0         0          None
# 2     1904.0    1927.0       23.0        0         0          None
# 3     2051.0    2052.0        1.0        0         0          None
# 4     2057.0    2056.0       -1.0        0         0          None
#
#    air_sys_delay  security_delay  airline_delay  late_aircraft_delay  \
# 0           93.0             0.0            0.0                  0.0
# 1            NaN             NaN            NaN                  NaN
# 2            0.0             0.0           19.0                  4.0
# 3            NaN             NaN            NaN                  NaN
# 4            NaN             NaN            NaN                  NaN
#
#    weather_delay airline_code          airline_name flight_date  \
# 0            0.0           NK      Spirit Air Lines  2015-01-04
# 1            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 2            0.0           DL  Delta Air Lines Inc.  2015-01-04
# 3            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 4            NaN           DL  Delta Air Lines Inc.  2015-01-05
#
#    avg_wind_orig  precip_orig  snow_orig  max_temp_orig  min_temp_orig  \
# 0           4.70          0.0        0.0           61.0           42.0
# 1           4.70          0.0        0.0           61.0           42.0
# 2           4.70          0.0        0.0           61.0           42.0
# 3           4.70          0.0        0.0           61.0           42.0
# 4           5.59          0.0        0.0           79.0           50.0
#
#    avg_wind_dest  precip_dest  snow_dest  max_temp_dest  min_temp_dest  \
# 0          11.86         0.12        0.8           36.0           19.0
# 1          11.86         0.12        0.8           36.0           19.0
# 2          11.86         0.12        0.8           36.0           19.0
# 3          11.86         0.12        0.8           36.0           19.0
# 4          13.65         0.00        0.2           19.0            8.0
#
#                    airport_name_orig    city_orig state_orig country_orig  \
# 0  Los Angeles International Airport  Los Angeles         CA          USA
# 1  Los Angeles International Airport  Los Angeles         CA          USA
# 2  Los Angeles International Airport  Los Angeles         CA          USA
# 3  Los Angeles International Airport  Los Angeles         CA          USA
# 4  Los Angeles International Airport  Los Angeles         CA          USA
#
#    lat_orig  long_orig                  airport_dest city_dest state_dest  \
# 0  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 1  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 2  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 3  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 4  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
#
#   country_dest  lat_dest  long_dest engine_manufacturer hour  total_delay  \
# 0          USA  42.21206  -83.34884                 IAE   22         93.0
# 1          USA  42.21206  -83.34884                CFMI   09          NaN
# 2          USA  42.21206  -83.34884                  PW   11         23.0
# 3          USA  42.21206  -83.34884                  PW   13          NaN
# 4          USA  42.21206  -83.34884                  PW   13          NaN
#
#    delayed  aircraft_age
# 0     True            10
# 1    False            17
# 2     True            14
# 3    False            17
# 4    False            15

# %%
# delete these because a flight would already be delayed by the time these are known
df_raw.drop(['depart_time','depart_delay','taxi_out','wheels_off','sched_time','elapsed_time',
            'air_time','wheels_on','taxi_in','sched_arr','arr_time','arr_delay'],axis=1,inplace=True)

# %%
df_raw.head()
# Out:
#   tail_num manufacturer model  month  day  day_of_week  flight_num  \
# 0   N502NK       Airbus  A319      1    4            7         709
# 1   N372DA       Boeing   737      1    4            7        1806
# 2   N550NW       Boeing   757      1    4            7        1706
# 3   N693DL       Boeing   757      1    4            7         870
# 4   N6706Q       Boeing   757      1    5            1        1876
#
#   orig_airport dest_airport  distance diverted cancelled cancel_reason  \
# 0          LAX          DTW      1979        0         0          None
# 1          LAX          DTW      1979        0         0          None
# 2          LAX          DTW      1979        0         0          None
# 3          LAX          DTW      1979        0         0          None
# 4          LAX          DTW      1979        0         0          None
#
#    air_sys_delay  security_delay  airline_delay  late_aircraft_delay  \
# 0           93.0             0.0            0.0                  0.0
# 1            NaN             NaN            NaN                  NaN
# 2            0.0             0.0           19.0                  4.0
# 3            NaN             NaN            NaN                  NaN
# 4            NaN             NaN            NaN                  NaN
#
#    weather_delay airline_code          airline_name flight_date  \
# 0            0.0           NK      Spirit Air Lines  2015-01-04
# 1            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 2            0.0           DL  Delta Air Lines Inc.  2015-01-04
# 3            NaN           DL  Delta Air Lines Inc.  2015-01-04
# 4            NaN           DL  Delta Air Lines Inc.  2015-01-05
#
#    avg_wind_orig  precip_orig  snow_orig  max_temp_orig  min_temp_orig  \
# 0           4.70          0.0        0.0           61.0           42.0
# 1           4.70          0.0        0.0           61.0           42.0
# 2           4.70          0.0        0.0           61.0           42.0
# 3           4.70          0.0        0.0           61.0           42.0
# 4           5.59          0.0        0.0           79.0           50.0
#
#    avg_wind_dest  precip_dest  snow_dest  max_temp_dest  min_temp_dest  \
# 0          11.86         0.12        0.8           36.0           19.0
# 1          11.86         0.12        0.8           36.0           19.0
# 2          11.86         0.12        0.8           36.0           19.0
# 3          11.86         0.12        0.8           36.0           19.0
# 4          13.65         0.00        0.2           19.0            8.0
#
#                    airport_name_orig    city_orig state_orig country_orig  \
# 0  Los Angeles International Airport  Los Angeles         CA          USA
# 1  Los Angeles International Airport  Los Angeles         CA          USA
# 2  Los Angeles International Airport  Los Angeles         CA          USA
# 3  Los Angeles International Airport  Los Angeles         CA          USA
# 4  Los Angeles International Airport  Los Angeles         CA          USA
#
#    lat_orig  long_orig                  airport_dest city_dest state_dest  \
# 0  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 1  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 2  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 3  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
# 4  33.94254 -118.40807  Detroit Metropolitan Airport   Detroit         MI
#
#   country_dest  lat_dest  long_dest engine_manufacturer hour  total_delay  \
# 0          USA  42.21206  -83.34884                 IAE   22         93.0
# 1          USA  42.21206  -83.34884                CFMI   09          NaN
# 2          USA  42.21206  -83.34884                  PW   11         23.0
# 3          USA  42.21206  -83.34884                  PW   13          NaN
# 4          USA  42.21206  -83.34884                  PW   13          NaN
#
#    delayed  aircraft_age
# 0     True            10
# 1    False            17
# 2     True            14
# 3    False            17
# 4    False            15

# %%
df_raw.airline_name.value_counts()
# Out:
# Southwest Airlines Co.    586792
# Delta Air Lines Inc.      289334
# United Air Lines Inc.     247457
# US Airways Inc.            67582
# JetBlue Airways            64082
# American Airlines Inc.     63753
# Spirit Air Lines           62245
# Alaska Airlines Inc.       52156
# Virgin America             38345
# Frontier Airlines Inc.     25073
# Hawaiian Airlines Inc.     10333
# Name: airline_name, dtype: int64

# %%
# drop US Airways and Virgin America because they no longer exist

df_raw = df_raw[df_raw.airline_name!='US Airways Inc.']
df_raw = df_raw[df_raw.airline_name!='Virgin America']

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1401225 entries, 0 to 1580817
# Data columns (total 48 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   tail_num             1401225 non-null  object
#  1   manufacturer         1401225 non-null  object
#  2   model                1401225 non-null  object
#  3   month                1401225 non-null  int64
#  4   day                  1401225 non-null  int64
#  5   day_of_week          1401225 non-null  int64
#  6   flight_num           1401225 non-null  int64
#  7   orig_airport         1401225 non-null  object
#  8   dest_airport         1401225 non-null  object
#  9   distance             1401225 non-null  int64
#  10  diverted             1401225 non-null  object
#  11  cancelled            1401225 non-null  object
#  12  cancel_reason        11717 non-null    object
#  13  air_sys_delay        274584 non-null   float64
#  14  security_delay       274584 non-null   float64
#  15  airline_delay        274584 non-null   float64
#  16  late_aircraft_delay  274584 non-null   float64
#  17  weather_delay        274584 non-null   float64
#  18  airline_code         1401225 non-null  object
#  19  airline_name         1401225 non-null  object
#  20  flight_date          1401225 non-null  object
#  21  avg_wind_orig        1401225 non-null  float64
#  22  precip_orig          1401225 non-null  float64
#  23  snow_orig            1401225 non-null  float64
#  24  max_temp_orig        1401225 non-null  float64
#  25  min_temp_orig        1401225 non-null  float64
#  26  avg_wind_dest        1401225 non-null  float64
#  27  precip_dest          1401225 non-null  float64
#  28  snow_dest            1401225 non-null  float64
#  29  max_temp_dest        1401225 non-null  float64
#  30  min_temp_dest        1401225 non-null  float64
#  31  airport_name_orig    1401225 non-null  object
#  32  city_orig            1401225 non-null  object
#  33  state_orig           1401225 non-null  object
#  34  country_orig         1401225 non-null  object
#  35  lat_orig             1401225 non-null  float64
#  36  long_orig            1401225 non-null  float64
#  37  airport_dest         1401225 non-null  object
#  38  city_dest            1401225 non-null  object
#  39  state_dest           1401225 non-null  object
#  40  country_dest         1401225 non-null  object
#  41  lat_dest             1401225 non-null  float64
#  42  long_dest            1401225 non-null  float64
#  43  engine_manufacturer  1401225 non-null  object
#  44  hour                 1401225 non-null  object
#  45  total_delay          274584 non-null   float64
#  46  delayed              1401225 non-null  bool
#  47  aircraft_age         1401225 non-null  int64
# dtypes: bool(1), float64(20), int64(6), object(21)
# memory usage: 514.5+ MB

# %%
# drop destination weather, diversions and cancellations (we're only predicting delays)
# drop sub-reasons for delay (we only need total delay)
# drop country because it's all USA

df_raw.drop(['avg_wind_dest','precip_dest','snow_dest','max_temp_dest','min_temp_dest',
            'diverted','cancelled','cancel_reason','air_sys_delay','security_delay',
            'airline_delay','late_aircraft_delay','weather_delay','country_orig',
            'country_dest'],axis=1,inplace=True)

# %% [markdown]
# Here I find, for each flight, was the exact aircraft to be used for that flight delayed on its previous flight, and was that flight on the same day? With the thinking that if the plane to be used for your flight was delayed earlier in the same day, the chances of your flight being delayed would be higher.  This turned out to be very true.

# %%
df_raw['flight_date'] = pd.to_datetime(df_raw.flight_date)

# %%
# sort by aircraft unique identifier and date for this to work
df_raw.sort_values(by=['tail_num','flight_date'],inplace=True)

# %%
df_raw.head(25)
# Out:
#         tail_num manufacturer model  month  day  day_of_week  flight_num  \
# 769672    N102UW       Airbus  A320      7   21            2        1829
# 1228456   N102UW       Airbus  A320      7   21            2         575
# 708469    N102UW       Airbus  A320      7   22            3        1789
# 700195    N102UW       Airbus  A320      8    9            7        1850
# 1069062   N102UW       Airbus  A320      8    9            7        1850
# 1230079   N102UW       Airbus  A320      8   10            1        1883
# 461649    N102UW       Airbus  A320      8   17            1        2058
# 714096    N102UW       Airbus  A320      8   17            1        1749
# 702394    N102UW       Airbus  A320      8   18            2        1917
# 1230124   N102UW       Airbus  A320      8   18            2        1883
# 714108    N102UW       Airbus  A320      8   20            4        2058
# 686356    N102UW       Airbus  A320      8   21            5         685
# 702406    N102UW       Airbus  A320      8   21            5         669
# 897208    N102UW       Airbus  A320      8   21            5         669
# 10159     N102UW       Airbus  A320      8   22            6        2004
# 686359    N102UW       Airbus  A320      8   22            6         776
# 897211    N102UW       Airbus  A320      8   22            6        1939
# 715401    N102UW       Airbus  A320      8   23            7         669
# 1230147   N102UW       Airbus  A320      8   23            7        1883
# 585828    N102UW       Airbus  A320      8   25            2         580
# 697132    N102UW       Airbus  A320      8   26            3        1845
# 708678    N102UW       Airbus  A320      9    1            2        1925
# 769779    N102UW       Airbus  A320      9    3            4        1829
# 1228576   N102UW       Airbus  A320      9    3            4         575
# 708694    N102UW       Airbus  A320      9    4            5        1789
#
#         orig_airport dest_airport  distance airline_code  \
# 769672           TPA          PHX      1788           AA
# 1228456          PHX          TPA      1788           AA
# 708469           TPA          PHL       920           AA
# 700195           MCO          PHL       861           AA
# 1069062          PHL          MCO       861           AA
# 1230079          PHL          TPA       920           AA
# 461649           PHL          BOS       280           AA
# 714096           MIA          PHL      1013           AA
# 702394           BOS          PHL       280           AA
# 1230124          PHL          TPA       920           AA
# 714108           MIA          PHL      1013           AA
# 686356           SEA          PHL      2378           AA
# 702406           BOS          PHL       280           AA
# 897208           PHL          SEA      2378           AA
# 10159            PHL          DTW       453           AA
# 686359           SEA          PHL      2378           AA
# 897211           PHL          SEA      2378           AA
# 715401           DTW          PHL       453           AA
# 1230147          PHL          TPA       920           AA
# 585828           PHL          DEN      1558           AA
# 697132           DEN          PHL      1558           AA
# 708678           TPA          PHL       920           AA
# 769779           TPA          PHX      1788           AA
# 1228576          PHX          TPA      1788           AA
# 708694           TPA          PHL       920           AA
#
#                    airline_name flight_date  avg_wind_orig  precip_orig  \
# 769672   American Airlines Inc.  2015-07-21           8.50         0.01
# 1228456  American Airlines Inc.  2015-07-21           6.71         0.00
# 708469   American Airlines Inc.  2015-07-22           7.16         0.04
# 700195   American Airlines Inc.  2015-08-09           6.26         0.00
# 1069062  American Airlines Inc.  2015-08-09           4.70         0.00
# 1230079  American Airlines Inc.  2015-08-10           8.05         0.04
# 461649   American Airlines Inc.  2015-08-17           8.50         0.00
# 714096   American Airlines Inc.  2015-08-17           8.95         0.06
# 702394   American Airlines Inc.  2015-08-18           8.05         0.14
# 1230124  American Airlines Inc.  2015-08-18           7.61         0.00
# 714108   American Airlines Inc.  2015-08-20           6.93         0.00
# 686356   American Airlines Inc.  2015-08-21           5.82         0.00
# 702406   American Airlines Inc.  2015-08-21           5.82         0.63
# 897208   American Airlines Inc.  2015-08-21           9.62         0.00
# 10159    American Airlines Inc.  2015-08-22           9.40         0.00
# 686359   American Airlines Inc.  2015-08-22           5.59         0.00
# 897211   American Airlines Inc.  2015-08-22           9.40         0.00
# 715401   American Airlines Inc.  2015-08-23           6.26         0.56
# 1230147  American Airlines Inc.  2015-08-23           4.92         0.00
# 585828   American Airlines Inc.  2015-08-25           8.50         0.00
# 697132   American Airlines Inc.  2015-08-26          10.29         0.00
# 708678   American Airlines Inc.  2015-09-01           5.82         0.00
# 769779   American Airlines Inc.  2015-09-03           4.47         0.00
# 1228576  American Airlines Inc.  2015-09-03           9.17         0.02
# 708694   American Airlines Inc.  2015-09-04           2.91         0.19
#
#          snow_orig  max_temp_orig  min_temp_orig  \
# 769672         0.0           89.0           81.0
# 1228456        0.0          106.0           85.0
# 708469         0.0           91.0           80.0
# 700195         0.0           94.0           74.0
# 1069062        0.0           86.0           71.0
# 1230079        0.0           79.0           69.0
# 461649         0.0           94.0           73.0
# 714096         0.0           91.0           79.0
# 702394         0.0           87.0           71.0
# 1230124        0.0           92.0           73.0
# 714108         0.0           91.0           81.0
# 686356         0.0           72.0           58.0
# 702406         0.0           83.0           67.0
# 897208         0.0           88.0           73.0
# 10159          0.0           86.0           68.0
# 686359         0.0           80.0           54.0
# 897211         0.0           86.0           68.0
# 715401         0.0           82.0           60.0
# 1230147        0.0           87.0           65.0
# 585828         0.0           89.0           72.0
# 697132         0.0           97.0           61.0
# 708678         0.0           91.0           78.0
# 769779         0.0           92.0           80.0
# 1228576        0.0          100.0           77.0
# 708694         0.0           91.0           77.0
#
#                                         airport_name_orig     city_orig  \
# 769672                        Tampa International Airport         Tampa
# 1228456          Phoenix Sky Harbor International Airport       Phoenix
# 708469                        Tampa International Airport         Tampa
# 700195                      Orlando International Airport       Orlando
# 1069062                Philadelphia International Airport  Philadelphia
# 1230079                Philadelphia International Airport  Philadelphia
# 461649                 Philadelphia International Airport  Philadelphia
# 714096                        Miami International Airport         Miami
# 702394   Gen. Edward Lawrence Logan International Airport        Boston
# 1230124                Philadelphia International Airport  Philadelphia
# 714108                        Miami International Airport         Miami
# 686356               Seattle-Tacoma International Airport       Seattle
# 702406   Gen. Edward Lawrence Logan International Airport        Boston
# 897208                 Philadelphia International Airport  Philadelphia
# 10159                  Philadelphia International Airport  Philadelphia
# 686359               Seattle-Tacoma International Airport       Seattle
# 897211                 Philadelphia International Airport  Philadelphia
# 715401                       Detroit Metropolitan Airport       Detroit
# 1230147                Philadelphia International Airport  Philadelphia
# 585828                 Philadelphia International Airport  Philadelphia
# 697132                       Denver International Airport        Denver
# 708678                        Tampa International Airport         Tampa
# 769779                        Tampa International Airport         Tampa
# 1228576          Phoenix Sky Harbor International Airport       Phoenix
# 708694                        Tampa International Airport         Tampa
#
#         state_orig  lat_orig  long_orig  \
# 769672          FL  27.97547  -82.53325
# 1228456         AZ  33.43417 -112.00806
# 708469          FL  27.97547  -82.53325
# 700195          FL  28.42889  -81.31603
# 1069062         PA  39.87195  -75.24114
# 1230079         PA  39.87195  -75.24114
# 461649          PA  39.87195  -75.24114
# 714096          FL  25.79325  -80.29056
# 702394          MA  42.36435  -71.00518
# 1230124         PA  39.87195  -75.24114
# 714108          FL  25.79325  -80.29056
# 686356          WA  47.44898 -122.30931
# 702406          MA  42.36435  -71.00518
# 897208          PA  39.87195  -75.24114
# 10159           PA  39.87195  -75.24114
# 686359          WA  47.44898 -122.30931
# 897211          PA  39.87195  -75.24114
# 715401          MI  42.21206  -83.34884
# 1230147         PA  39.87195  -75.24114
# 585828          PA  39.87195  -75.24114
# 697132          CO  39.85841 -104.66700
# 708678          FL  27.97547  -82.53325
# 769779          FL  27.97547  -82.53325
# 1228576         AZ  33.43417 -112.00806
# 708694          FL  27.97547  -82.53325
#
#                                              airport_dest     city_dest  \
# 769672           Phoenix Sky Harbor International Airport       Phoenix
# 1228456                       Tampa International Airport         Tampa
# 708469                 Philadelphia International Airport  Philadelphia
# 700195                 Philadelphia International Airport  Philadelphia
# 1069062                     Orlando International Airport       Orlando
# 1230079                       Tampa International Airport         Tampa
# 461649   Gen. Edward Lawrence Logan International Airport        Boston
# 714096                 Philadelphia International Airport  Philadelphia
# 702394                 Philadelphia International Airport  Philadelphia
# 1230124                       Tampa International Airport         Tampa
# 714108                 Philadelphia International Airport  Philadelphia
# 686356                 Philadelphia International Airport  Philadelphia
# 702406                 Philadelphia International Airport  Philadelphia
# 897208               Seattle-Tacoma International Airport       Seattle
# 10159                        Detroit Metropolitan Airport       Detroit
# 686359                 Philadelphia International Airport  Philadelphia
# 897211               Seattle-Tacoma International Airport       Seattle
# 715401                 Philadelphia International Airport  Philadelphia
# 1230147                       Tampa International Airport         Tampa
# 585828                       Denver International Airport        Denver
# 697132                 Philadelphia International Airport  Philadelphia
# 708678                 Philadelphia International Airport  Philadelphia
# 769779           Phoenix Sky Harbor International Airport       Phoenix
# 1228576                       Tampa International Airport         Tampa
# 708694                 Philadelphia International Airport  Philadelphia
#
#         state_dest  lat_dest  long_dest engine_manufacturer hour  total_delay  \
# 769672          AZ  33.43417 -112.00806                CFMI   20          NaN
# 1228456         FL  27.97547  -82.53325                CFMI   23          NaN
# 708469          PA  39.87195  -75.24114                CFMI   07          NaN
# 700195          PA  39.87195  -75.24114                CFMI   10          NaN
# 1069062         FL  28.42889  -81.31603                CFMI   07          NaN
# 1230079         FL  27.97547  -82.53325                CFMI   18          NaN
# 461649          MA  42.36435  -71.00518                CFMI   20          NaN
# 714096          PA  39.87195  -75.24114                CFMI   16          NaN
# 702394          PA  39.87195  -75.24114                CFMI   07          NaN
# 1230124         FL  27.97547  -82.53325                CFMI   18         31.0
# 714108          PA  39.87195  -75.24114                CFMI   16          NaN
# 686356          PA  39.87195  -75.24114                CFMI   13         17.0
# 702406          PA  39.87195  -75.24114                CFMI   06         47.0
# 897208          WA  47.44898 -122.30931                CFMI   09         31.0
# 10159           MI  42.21206  -83.34884                CFMI   21          NaN
# 686359          PA  39.87195  -75.24114                CFMI   11          NaN
# 897211          WA  47.44898 -122.30931                CFMI   07          NaN
# 715401          PA  39.87195  -75.24114                CFMI   07          NaN
# 1230147         FL  27.97547  -82.53325                CFMI   18          NaN
# 585828          CO  39.85841 -104.66700                CFMI   20          NaN
# 697132          PA  39.87195  -75.24114                CFMI   00          NaN
# 708678          PA  39.87195  -75.24114                CFMI   12          NaN
# 769779          AZ  33.43417 -112.00806                CFMI   20          NaN
# 1228576         FL  27.97547  -82.53325                CFMI   23          NaN
# 708694          PA  39.87195  -75.24114                CFMI   07          NaN
#
#          delayed  aircraft_age
# 769672     False            17
# 1228456    False            17
# 708469     False            17
# 700195     False            17
# 1069062    False            17
# 1230079    False            17
# 461649     False            17
# 714096     False            17
# 702394     False            17
# 1230124     True            17
# 714108     False            17
# 686356      True            17
# 702406      True            17
# 897208      True            17
# 10159      False            17
# 686359     False            17
# 897211     False            17
# 715401     False            17
# 1230147    False            17
# 585828     False            17
# 697132     False            17
# 708678     False            17
# 769779     False            17
# 1228576    False            17
# 708694     False            17

# %%
# only if same day flight condition
df_raw['same_date'] = df_raw.flight_date.dt.date == df_raw.flight_date.dt.date.shift(1)

# only if same aircraft condition 
df_raw['same_plane'] = df_raw.tail_num == df_raw.tail_num.shift(1)

# %%
df_raw.head(20)[['flight_date','same_date','same_plane']]
# Out:
#         flight_date  same_date  same_plane
# 769672   2015-07-21      False       False
# 1228456  2015-07-21       True        True
# 708469   2015-07-22      False        True
# 700195   2015-08-09      False        True
# 1069062  2015-08-09       True        True
# 1230079  2015-08-10      False        True
# 461649   2015-08-17      False        True
# 714096   2015-08-17       True        True
# 702394   2015-08-18      False        True
# 1230124  2015-08-18       True        True
# 714108   2015-08-20      False        True
# 686356   2015-08-21      False        True
# 702406   2015-08-21       True        True
# 897208   2015-08-21       True        True
# 10159    2015-08-22      False        True
# 686359   2015-08-22       True        True
# 897211   2015-08-22       True        True
# 715401   2015-08-23      False        True
# 1230147  2015-08-23       True        True
# 585828   2015-08-25      False        True

# %%
df_raw['previous_delay'] = np.where((df_raw.same_date) & (df_raw.same_plane),df_raw.delayed.shift(1),False)

# %%
df_raw.drop(['same_date','same_plane'],axis=1,inplace=True)

# %%
df_raw.head(20)
# Out:
#         tail_num manufacturer model  month  day  day_of_week  flight_num  \
# 769672    N102UW       Airbus  A320      7   21            2        1829
# 1228456   N102UW       Airbus  A320      7   21            2         575
# 708469    N102UW       Airbus  A320      7   22            3        1789
# 700195    N102UW       Airbus  A320      8    9            7        1850
# 1069062   N102UW       Airbus  A320      8    9            7        1850
# 1230079   N102UW       Airbus  A320      8   10            1        1883
# 461649    N102UW       Airbus  A320      8   17            1        2058
# 714096    N102UW       Airbus  A320      8   17            1        1749
# 702394    N102UW       Airbus  A320      8   18            2        1917
# 1230124   N102UW       Airbus  A320      8   18            2        1883
# 714108    N102UW       Airbus  A320      8   20            4        2058
# 686356    N102UW       Airbus  A320      8   21            5         685
# 702406    N102UW       Airbus  A320      8   21            5         669
# 897208    N102UW       Airbus  A320      8   21            5         669
# 10159     N102UW       Airbus  A320      8   22            6        2004
# 686359    N102UW       Airbus  A320      8   22            6         776
# 897211    N102UW       Airbus  A320      8   22            6        1939
# 715401    N102UW       Airbus  A320      8   23            7         669
# 1230147   N102UW       Airbus  A320      8   23            7        1883
# 585828    N102UW       Airbus  A320      8   25            2         580
#
#         orig_airport dest_airport  distance airline_code  \
# 769672           TPA          PHX      1788           AA
# 1228456          PHX          TPA      1788           AA
# 708469           TPA          PHL       920           AA
# 700195           MCO          PHL       861           AA
# 1069062          PHL          MCO       861           AA
# 1230079          PHL          TPA       920           AA
# 461649           PHL          BOS       280           AA
# 714096           MIA          PHL      1013           AA
# 702394           BOS          PHL       280           AA
# 1230124          PHL          TPA       920           AA
# 714108           MIA          PHL      1013           AA
# 686356           SEA          PHL      2378           AA
# 702406           BOS          PHL       280           AA
# 897208           PHL          SEA      2378           AA
# 10159            PHL          DTW       453           AA
# 686359           SEA          PHL      2378           AA
# 897211           PHL          SEA      2378           AA
# 715401           DTW          PHL       453           AA
# 1230147          PHL          TPA       920           AA
# 585828           PHL          DEN      1558           AA
#
#                    airline_name flight_date  avg_wind_orig  precip_orig  \
# 769672   American Airlines Inc.  2015-07-21           8.50         0.01
# 1228456  American Airlines Inc.  2015-07-21           6.71         0.00
# 708469   American Airlines Inc.  2015-07-22           7.16         0.04
# 700195   American Airlines Inc.  2015-08-09           6.26         0.00
# 1069062  American Airlines Inc.  2015-08-09           4.70         0.00
# 1230079  American Airlines Inc.  2015-08-10           8.05         0.04
# 461649   American Airlines Inc.  2015-08-17           8.50         0.00
# 714096   American Airlines Inc.  2015-08-17           8.95         0.06
# 702394   American Airlines Inc.  2015-08-18           8.05         0.14
# 1230124  American Airlines Inc.  2015-08-18           7.61         0.00
# 714108   American Airlines Inc.  2015-08-20           6.93         0.00
# 686356   American Airlines Inc.  2015-08-21           5.82         0.00
# 702406   American Airlines Inc.  2015-08-21           5.82         0.63
# 897208   American Airlines Inc.  2015-08-21           9.62         0.00
# 10159    American Airlines Inc.  2015-08-22           9.40         0.00
# 686359   American Airlines Inc.  2015-08-22           5.59         0.00
# 897211   American Airlines Inc.  2015-08-22           9.40         0.00
# 715401   American Airlines Inc.  2015-08-23           6.26         0.56
# 1230147  American Airlines Inc.  2015-08-23           4.92         0.00
# 585828   American Airlines Inc.  2015-08-25           8.50         0.00
#
#          snow_orig  max_temp_orig  min_temp_orig  \
# 769672         0.0           89.0           81.0
# 1228456        0.0          106.0           85.0
# 708469         0.0           91.0           80.0
# 700195         0.0           94.0           74.0
# 1069062        0.0           86.0           71.0
# 1230079        0.0           79.0           69.0
# 461649         0.0           94.0           73.0
# 714096         0.0           91.0           79.0
# 702394         0.0           87.0           71.0
# 1230124        0.0           92.0           73.0
# 714108         0.0           91.0           81.0
# 686356         0.0           72.0           58.0
# 702406         0.0           83.0           67.0
# 897208         0.0           88.0           73.0
# 10159          0.0           86.0           68.0
# 686359         0.0           80.0           54.0
# 897211         0.0           86.0           68.0
# 715401         0.0           82.0           60.0
# 1230147        0.0           87.0           65.0
# 585828         0.0           89.0           72.0
#
#                                         airport_name_orig     city_orig  \
# 769672                        Tampa International Airport         Tampa
# 1228456          Phoenix Sky Harbor International Airport       Phoenix
# 708469                        Tampa International Airport         Tampa
# 700195                      Orlando International Airport       Orlando
# 1069062                Philadelphia International Airport  Philadelphia
# 1230079                Philadelphia International Airport  Philadelphia
# 461649                 Philadelphia International Airport  Philadelphia
# 714096                        Miami International Airport         Miami
# 702394   Gen. Edward Lawrence Logan International Airport        Boston
# 1230124                Philadelphia International Airport  Philadelphia
# 714108                        Miami International Airport         Miami
# 686356               Seattle-Tacoma International Airport       Seattle
# 702406   Gen. Edward Lawrence Logan International Airport        Boston
# 897208                 Philadelphia International Airport  Philadelphia
# 10159                  Philadelphia International Airport  Philadelphia
# 686359               Seattle-Tacoma International Airport       Seattle
# 897211                 Philadelphia International Airport  Philadelphia
# 715401                       Detroit Metropolitan Airport       Detroit
# 1230147                Philadelphia International Airport  Philadelphia
# 585828                 Philadelphia International Airport  Philadelphia
#
#         state_orig  lat_orig  long_orig  \
# 769672          FL  27.97547  -82.53325
# 1228456         AZ  33.43417 -112.00806
# 708469          FL  27.97547  -82.53325
# 700195          FL  28.42889  -81.31603
# 1069062         PA  39.87195  -75.24114
# 1230079         PA  39.87195  -75.24114
# 461649          PA  39.87195  -75.24114
# 714096          FL  25.79325  -80.29056
# 702394          MA  42.36435  -71.00518
# 1230124         PA  39.87195  -75.24114
# 714108          FL  25.79325  -80.29056
# 686356          WA  47.44898 -122.30931
# 702406          MA  42.36435  -71.00518
# 897208          PA  39.87195  -75.24114
# 10159           PA  39.87195  -75.24114
# 686359          WA  47.44898 -122.30931
# 897211          PA  39.87195  -75.24114
# 715401          MI  42.21206  -83.34884
# 1230147         PA  39.87195  -75.24114
# 585828          PA  39.87195  -75.24114
#
#                                              airport_dest     city_dest  \
# 769672           Phoenix Sky Harbor International Airport       Phoenix
# 1228456                       Tampa International Airport         Tampa
# 708469                 Philadelphia International Airport  Philadelphia
# 700195                 Philadelphia International Airport  Philadelphia
# 1069062                     Orlando International Airport       Orlando
# 1230079                       Tampa International Airport         Tampa
# 461649   Gen. Edward Lawrence Logan International Airport        Boston
# 714096                 Philadelphia International Airport  Philadelphia
# 702394                 Philadelphia International Airport  Philadelphia
# 1230124                       Tampa International Airport         Tampa
# 714108                 Philadelphia International Airport  Philadelphia
# 686356                 Philadelphia International Airport  Philadelphia
# 702406                 Philadelphia International Airport  Philadelphia
# 897208               Seattle-Tacoma International Airport       Seattle
# 10159                        Detroit Metropolitan Airport       Detroit
# 686359                 Philadelphia International Airport  Philadelphia
# 897211               Seattle-Tacoma International Airport       Seattle
# 715401                 Philadelphia International Airport  Philadelphia
# 1230147                       Tampa International Airport         Tampa
# 585828                       Denver International Airport        Denver
#
#         state_dest  lat_dest  long_dest engine_manufacturer hour  total_delay  \
# 769672          AZ  33.43417 -112.00806                CFMI   20          NaN
# 1228456         FL  27.97547  -82.53325                CFMI   23          NaN
# 708469          PA  39.87195  -75.24114                CFMI   07          NaN
# 700195          PA  39.87195  -75.24114                CFMI   10          NaN
# 1069062         FL  28.42889  -81.31603                CFMI   07          NaN
# 1230079         FL  27.97547  -82.53325                CFMI   18          NaN
# 461649          MA  42.36435  -71.00518                CFMI   20          NaN
# 714096          PA  39.87195  -75.24114                CFMI   16          NaN
# 702394          PA  39.87195  -75.24114                CFMI   07          NaN
# 1230124         FL  27.97547  -82.53325                CFMI   18         31.0
# 714108          PA  39.87195  -75.24114                CFMI   16          NaN
# 686356          PA  39.87195  -75.24114                CFMI   13         17.0
# 702406          PA  39.87195  -75.24114                CFMI   06         47.0
# 897208          WA  47.44898 -122.30931                CFMI   09         31.0
# 10159           MI  42.21206  -83.34884                CFMI   21          NaN
# 686359          PA  39.87195  -75.24114                CFMI   11          NaN
# 897211          WA  47.44898 -122.30931                CFMI   07          NaN
# 715401          PA  39.87195  -75.24114                CFMI   07          NaN
# 1230147         FL  27.97547  -82.53325                CFMI   18          NaN
# 585828          CO  39.85841 -104.66700                CFMI   20          NaN
#
#          delayed  aircraft_age previous_delay
# 769672     False            17              0
# 1228456    False            17          False
# 708469     False            17              0
# 700195     False            17              0
# 1069062    False            17          False
# 1230079    False            17              0
# 461649     False            17              0
# 714096     False            17          False
# 702394     False            17              0
# 1230124     True            17          False
# 714108     False            17              0
# 686356      True            17              0
# 702406      True            17           True
# 897208      True            17           True
# 10159      False            17              0
# 686359     False            17          False
# 897211     False            17          False
# 715401     False            17              0
# 1230147    False            17          False
# 585828     False            17              0

# %% [markdown]
# Now I do some feature engineering.  Because a lot of my variables are categorical with high value counts, I needed another way besides one-hot encoding to capture the effect of these features.  For each one, I took the percent of flights delayed for each column value.

# %%
delays_by_airport = flights.groupby('orig_airport',as_index=False).agg({'delayed':'mean'}).rename(columns={'delayed': 'airport_delayed'})
flights = flights.merge(delays_by_airport,on='orig_airport')

# %%
delays_by_airline = flights.groupby('airline_name',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'airline_delayed'})
flights = flights.merge(delays_by_airline,on='airline_name')

# %%
delays_by_hour = flights.groupby('hour',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'hour_delayed'})
flights = flights.merge(delays_by_hour,on='hour')

delays_by_month = flights.groupby('month',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'month_delayed'})
flights = flights.merge(delays_by_month,on='month')

delays_by_weekday = flights.groupby('day_of_week',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'weekday_delayed'})
flights = flights.merge(delays_by_weekday,on='day_of_week')

delays_by_aircraft_model = flights.groupby('model',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'model_delayed'})
flights = flights.merge(delays_by_aircraft_model,on='model')

delays_by_engine = flights.groupby('engine_manufacturer',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'engine_delayed'})
flights = flights.merge(delays_by_engine,on='engine_manufacturer')

delays_by_aircraft = flights.groupby('tail_num',as_index=False).agg({'delayed': 'mean'}).rename(
    columns={'delayed': 'aircraft_delayed'})
flights = flights.merge(delays_by_aircraft,on='tail_num')

# %%
flights.head()
# Out:
#   tail_num manufacturer model  month  day  day_of_week  flight_num  \
# 0   N102UW       Airbus  A320      7   21            2        1829
# 1   N102UW       Airbus  A320      7   21            2         575
# 2   N102UW       Airbus  A320      9    1            2        1925
# 3   N102UW       Airbus  A320      9   15            2        1955
# 4   N102UW       Airbus  A320     11   17            2        2058
#
#   orig_airport dest_airport  distance  ... aircraft_age previous_delay  \
# 0          TPA          PHX      1788  ...           17          False
# 1          PHX          TPA      1788  ...           17          False
# 2          TPA          PHL       920  ...           17          False
# 3          PHL          TPA       920  ...           17          False
# 4          PHL          BOS       280  ...           17          False
#
#   airport_delayed  airline_delayed  hour_delayed  month_delayed  \
# 0        0.187791         0.171255      0.292438       0.231314
# 1        0.196470         0.171255      0.220926       0.231314
# 2        0.187791         0.171255      0.187565       0.128492
# 3        0.198631         0.171255      0.232860       0.128492
# 4        0.198631         0.171255      0.292438       0.151843
#
#    weekday_delayed  model_delayed engine_delayed aircraft_delayed
# 0         0.200221       0.216617       0.191086         0.135593
# 1         0.200221       0.216617       0.191086         0.135593
# 2         0.200221       0.216617       0.191086         0.135593
# 3         0.200221       0.216617       0.191086         0.135593
# 4         0.200221       0.216617       0.191086         0.135593
#
# [5 rows x 42 columns]

# %%
flights.to_csv('flights_final.csv',index=False)
